# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhas333/pandas-and-numpy/blob/main/day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bbhj
